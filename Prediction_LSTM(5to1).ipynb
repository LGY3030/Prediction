# %%
import pandas as pd
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten, LSTM, TimeDistributed, RepeatVector
from keras.layers.normalization import BatchNormalization
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.utils import np_utils
import keras
import matplotlib.pyplot as plt
import os
from sklearn import preprocessing
from sklearn.utils import shuffle
# Out:
# C:\Users\admin\Anaconda3\envs\tensorflow\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
# 把所有年份的資料merge在一起,並存在data.csv裡
def mergeData():
    SaveFile_Name = 'data.csv'
    file_list = os.listdir('data')
    df = pd.read_csv('data'+'\\'+file_list[0])
    df.to_csv(SaveFile_Name,encoding="utf_8_sig",index=False)
    for i in range(1,len(file_list)):
        df = pd.read_csv('data'+'\\'+file_list[i])
        df.to_csv(SaveFile_Name,encoding="utf_8_sig",index=False, header=False, mode='a+')

# %%
# 讀取data.csv
def readData():
    train = pd.read_csv("data.csv")
    return train

# %%
# 把年份換成西元年
def changeYear(data):
    for i in range(0,data.shape[0]):
        Date=data["日期"][i].split('/')
        year,month,date=Date[0],Date[1],Date[2]
        year=str(int(year)+1911)
        data.loc[i,"日期"]=year+'/'+month+'/'+date
    return data

# %%
# 增加features("年","月","日","第幾日")
def augFeatures(data):
  data["日期"] = pd.to_datetime(data["日期"])
  data["年"] = data["日期"].dt.year
  data["月"] = data["日期"].dt.month
  data["日"] = data["日期"].dt.day
  data["第幾日"] = data["日期"].dt.dayofweek
  return data

# %%
# 把非數字的資料換成正確資料,並減少features("日期","成交股數","成交金額",等等...)
def manage(data):
    for i in range(0,data.shape[0]):
        if data["漲跌價差"][i]=='X0.00':
            data.loc[i,"漲跌價差"]=str(int(data["收盤價"][i])-int(data["收盤價"][i-1]))
    data=data.drop(["日期"], axis=1)
    data=data.drop(["成交股數"], axis=1)
    data=data.drop(["成交金額"], axis=1)
    data=data.drop(["漲跌價差"], axis=1)
    data=data.drop(["成交筆數"], axis=1)
    data=data.convert_objects(convert_numeric=True)
    return data

# %%
# 把資料normalize
def normalize(train):
    train = train.apply(lambda x: (x - np.mean(x)) / (np.max(x) - np.min(x)))
    return train

# %%
# 創造出train的資料,train_x為輸入資料(所有features),train_y為輸出資料(開盤價的成長率,分為9個區段)
def buildTrain(train, pastDay=10, futureDay=1):
    X_train, Y_train, Z_train, W_train= [], [], [], []
    X,Y,Z,W=[],[],[],[]
    for i in range(train.shape[0]-futureDay-pastDay):
        X_train.append(np.array(train.iloc[i:i+pastDay]))
        Y_train.append(np.array(train.iloc[i+pastDay:i+pastDay+futureDay]["開盤價"]))
        Z_train.append(np.array(train.iloc[i+pastDay-1:i+pastDay]["開盤價"]))
        W_train.append(np.array(train.iloc[i:i+1]["開盤價"]))
    X=np.array(X_train)
    Y=np.array(Y_train)
    Z=np.array(Z_train)
    W=np.array(W_train)
    Z=(Z+W)/2
    Y=100*((Y-Z)/Z)
    Y_train=[]
    
    for i in range(len(Y)):
        if Y[i]<-3.5:
            Y_train.append(np.array([0]))
        elif -3.5<=Y[i]<-2.5:
            Y_train.append(np.array([1]))
        elif -2.5<=Y[i]<-1.5:
            Y_train.append(np.array([2]))
        elif -1.5<=Y[i]<-0.5:
            Y_train.append(np.array([3]))
        elif -0.5<=Y[i]<0.5:
            Y_train.append(np.array([4]))
        elif 0.5<=Y[i]<1.5:
            Y_train.append(np.array([5]))
        elif 1.5<=Y[i]<2.5:
            Y_train.append(np.array([6]))
        elif 2.5<=Y[i]<3.5:
            Y_train.append(np.array([7]))
        else:
            Y_train.append(np.array([8]))
    Y=np.array(Y_train)
    
    return X, Y
'''
def buildTrain(train, pastDay=5, futureDay=1):
    X_train, Y_train, Z_train, a_train, b_train, c_train, d_train= [], [], [], [], [], [], []
    X,Y,Z,a,b,c,d=[],[],[],[],[],[],[]
    for i in range(train.shape[0]-futureDay-pastDay):
        X_train.append(np.array(train.iloc[i:i+pastDay]))
        Y_train.append(np.array(train.iloc[i+pastDay:i+pastDay+futureDay]["開盤價"]))
        Z_train.append(np.array(train.iloc[i+pastDay-1:i+pastDay]["開盤價"]))
        a_train.append(np.array(train.iloc[i:i+1]["開盤價"]))
        b_train.append(np.array(train.iloc[i+1:i+2]["開盤價"]))
        c_train.append(np.array(train.iloc[i+2:i+3]["開盤價"]))
        d_train.append(np.array(train.iloc[i+3:i+4]["開盤價"]))
    X=np.array(X_train)
    Y=np.array(Y_train)
    Z=np.array(Z_train)
    a=np.array(a_train)
    b=np.array(b_train)
    c=np.array(c_train)
    d=np.array(d_train)
    Z=(Z+a+b+c+d)/5
    Y=100*((Y-Z)/Z)
    Y_train=[]
    
    for i in range(len(Y)):
        if Y[i]<-3.5:
            Y_train.append(np.array([0]))
        elif -3.5<=Y[i]<-2.5:
            Y_train.append(np.array([1]))
        elif -2.5<=Y[i]<-1.5:
            Y_train.append(np.array([2]))
        elif -1.5<=Y[i]<-0.5:
            Y_train.append(np.array([3]))
        elif -0.5<=Y[i]<0.5:
            Y_train.append(np.array([4]))
        elif 0.5<=Y[i]<1.5:
            Y_train.append(np.array([5]))
        elif 1.5<=Y[i]<2.5:
            Y_train.append(np.array([6]))
        elif 2.5<=Y[i]<3.5:
            Y_train.append(np.array([7]))
        else:
            Y_train.append(np.array([8]))
    Y=np.array(Y_train)
    
    return X, Y
'''
# Out:
# '\ndef buildTrain(train, pastDay=5, futureDay=1):\n    X_train, Y_train, Z_train, a_train, b_train, c_train, d_train= [], [], [], [], [], [], []\n    X,Y,Z,a,b,c,d=[],[],[],[],[],[],[]\n    for i in range(train.shape[0]-futureDay-pastDay):\n        X_train.append(np.array(train.iloc[i:i+pastDay]))\n        Y_train.append(np.array(train.iloc[i+pastDay:i+pastDay+futureDay]["開盤價"]))\n        Z_train.append(np.array(train.iloc[i+pastDay-1:i+pastDay]["開盤價"]))\n        a_train.append(np.array(train.iloc[i:i+1]["開盤價"]))\n        b_train.append(np.array(train.iloc[i+1:i+2]["開盤價"]))\n        c_train.append(np.array(train.iloc[i+2:i+3]["開盤價"]))\n        d_train.append(np.array(train.iloc[i+3:i+4]["開盤價"]))\n    X=np.array(X_train)\n    Y=np.array(Y_train)\n    Z=np.array(Z_train)\n    a=np.array(a_train)\n    b=np.array(b_train)\n    c=np.array(c_train)\n    d=np.array(d_train)\n    Z=(Z+a+b+c+d)/5\n    Y=100*((Y-Z)/Z)\n    Y_train=[]\n    \n    for i in range(len(Y)):\n        if Y[i]<-3.5:\n            Y_train.append(np.array([0]))\n        elif -3.5<=Y[i]<-2.5:\n            Y_train.append(np.array([1]))\n        elif -2.5<=Y[i]<-1.5:\n            Y_train.append(np.array([2]))\n        elif -1.5<=Y[i]<-0.5:\n            Y_train.append(np.array([3]))\n        elif -0.5<=Y[i]<0.5:\n            Y_train.append(np.array([4]))\n        elif 0.5<=Y[i]<1.5:\n            Y_train.append(np.array([5]))\n        elif 1.5<=Y[i]<2.5:\n            Y_train.append(np.array([6]))\n        elif 2.5<=Y[i]<3.5:\n            Y_train.append(np.array([7]))\n        else:\n            Y_train.append(np.array([8]))\n    Y=np.array(Y_train)\n    \n    return X, Y\n'

# %%
# 把資料打亂
def shuffle(X,Y):
    np.random.seed()
    randomList = np.arange(X.shape[0])
    np.random.shuffle(randomList)
    return X[randomList], Y[randomList]

# %%
# 將資料分成訓練資料和測試資料
def splitData(X,Y,rate):
    X_train = X[:-int(X.shape[0]*rate)]

    Y_train = Y[:-int(Y.shape[0]*rate)]
    
    X_val = X[-int(X.shape[0]*rate):]

    Y_val = Y[-int(Y.shape[0]*rate):]
    return X_train, Y_train, X_val, Y_val

# %%
# 建立模型
def buildModel(shape):
    model = Sequential()
    model.add(LSTM(150,input_shape=(shape[1],shape[2]),return_sequences=True))
    model.add(Dropout(0.4))
    model.add(LSTM(150))
    model.add(Dropout(0.4))
    model.add(Dense(9))
    model.add(Activation('softmax'))
    model.compile(loss="categorical_crossentropy", optimizer='adam',metrics=['accuracy'])
    model.summary()
    return model

# %%
# 印出loss, accuracy,val_loss, val_accuracy
class History(keras.callbacks.Callback):
    def on_train_begin(self, logs={}):
        self.losses = {'batch':[], 'epoch':[]}
        self.accuracy = {'batch':[], 'epoch':[]}
        self.val_loss = {'batch':[], 'epoch':[]}
        self.val_acc = {'batch':[], 'epoch':[]}
 
    def on_batch_end(self, batch, logs={}):
        self.losses['batch'].append(logs.get('loss'))
        self.accuracy['batch'].append(logs.get('acc'))
        self.val_loss['batch'].append(logs.get('val_loss'))
        self.val_acc['batch'].append(logs.get('val_acc'))
 
    def on_epoch_end(self, batch, logs={}):
        self.losses['epoch'].append(logs.get('loss'))
        self.accuracy['epoch'].append(logs.get('acc'))
        self.val_loss['epoch'].append(logs.get('val_loss'))
        self.val_acc['epoch'].append(logs.get('val_acc'))
 
    def loss_plot(self, loss_type):
        iters = range(len(self.losses[loss_type]))
        plt.figure()
        # acc
        plt.plot(iters, self.accuracy[loss_type], 'r', label='train acc')
        # loss
        plt.plot(iters, self.losses[loss_type], 'g', label='train loss')
        if loss_type == 'epoch':
            # val_acc
            plt.plot(iters, self.val_acc[loss_type], 'b', label='val acc')
            # val_loss
            plt.plot(iters, self.val_loss[loss_type], 'k', label='val loss')
        plt.grid(True)
        plt.xlabel(loss_type)
        plt.ylabel('acc-loss')
        plt.legend(loc="upper right")
        plt.show()

# %%
mergeData()
train=readData()
train=changeYear(train)
train=augFeatures(train)
train=manage(train)
train=train.drop(["最高價"], axis=1)
train=train.drop(["最低價"], axis=1)
temp=train
train=normalize(train)
train_x1, train_y1 = buildTrain(train,5,1)
train_x2, train_y2 = buildTrain(temp,5,1)
train_x, train_y = train_x1,train_y2 
train_y=np_utils.to_categorical(train_y)
train_x, train_y = shuffle(train_x, train_y )
train_x, train_y , test_x, test_y = splitData(train_x, train_y , 0.1)
history = History()
model = buildModel(train_x.shape)
callback = EarlyStopping(monitor="loss", patience=10, verbose=1, mode="auto")
model.fit(train_x, train_y, epochs=150, batch_size=360, verbose=2,validation_split=0.1, callbacks=[callback,history])
# Out:
# C:\Users\admin\Anaconda3\envs\tensorflow\lib\site-packages\ipykernel_launcher.py:11: FutureWarning: convert_objects is deprecated.  To re-infer data dtypes for object columns, use DataFrame.infer_objects()
# For all other conversions use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   # This is added back by InteractiveShellApp.init_path()
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_1 (LSTM)                (None, 5, 150)            94200
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 5, 150)            0
# _________________________________________________________________
# lstm_2 (LSTM)                (None, 150)               180600
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 150)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 9)                 1359
# _________________________________________________________________
# activation_1 (Activation)    (None, 9)                 0
# =================================================================
# Total params: 276,159
# Trainable params: 276,159
# Non-trainable params: 0
# _________________________________________________________________
# Train on 5010 samples, validate on 557 samples
# Epoch 1/150
#  - 4s - loss: 2.1761 - acc: 0.1643 - val_loss: 2.1424 - val_acc: 0.1670
# Epoch 2/150
#  - 1s - loss: 2.1108 - acc: 0.1948 - val_loss: 2.0956 - val_acc: 0.1867
# Epoch 3/150
#  - 1s - loss: 2.0859 - acc: 0.1898 - val_loss: 2.0971 - val_acc: 0.1813
# Epoch 4/150
#  - 1s - loss: 2.0845 - acc: 0.1942 - val_loss: 2.0909 - val_acc: 0.1724
# Epoch 5/150
#  - 1s - loss: 2.0817 - acc: 0.1948 - val_loss: 2.0923 - val_acc: 0.1741
# Epoch 6/150
#  - 1s - loss: 2.0824 - acc: 0.1972 - val_loss: 2.0910 - val_acc: 0.1652
# Epoch 7/150
#  - 1s - loss: 2.0816 - acc: 0.1916 - val_loss: 2.0927 - val_acc: 0.1652
# Epoch 8/150
#  - 1s - loss: 2.0808 - acc: 0.1902 - val_loss: 2.0900 - val_acc: 0.1670
# Epoch 9/150
#  - 1s - loss: 2.0810 - acc: 0.1918 - val_loss: 2.0909 - val_acc: 0.1652
# Epoch 10/150
#  - 1s - loss: 2.0791 - acc: 0.1936 - val_loss: 2.0922 - val_acc: 0.1724
# Epoch 11/150
#  - 1s - loss: 2.0789 - acc: 0.1972 - val_loss: 2.0869 - val_acc: 0.1706
# Epoch 12/150
#  - 1s - loss: 2.0755 - acc: 0.2024 - val_loss: 2.0888 - val_acc: 0.1688
# Epoch 13/150
#  - 1s - loss: 2.0745 - acc: 0.2008 - val_loss: 2.0855 - val_acc: 0.1688
# Epoch 14/150
#  - 1s - loss: 2.0759 - acc: 0.1918 - val_loss: 2.0870 - val_acc: 0.1706
# Epoch 15/150
#  - 1s - loss: 2.0756 - acc: 0.2032 - val_loss: 2.0911 - val_acc: 0.1688
# Epoch 16/150
#  - 1s - loss: 2.0764 - acc: 0.1988 - val_loss: 2.0842 - val_acc: 0.1724
# Epoch 17/150
#  - 1s - loss: 2.0764 - acc: 0.1990 - val_loss: 2.0877 - val_acc: 0.1777
# Epoch 18/150
#  - 1s - loss: 2.0734 - acc: 0.2046 - val_loss: 2.0831 - val_acc: 0.1741
# Epoch 19/150
#  - 1s - loss: 2.0736 - acc: 0.1990 - val_loss: 2.0867 - val_acc: 0.1634
# Epoch 20/150
#  - 1s - loss: 2.0718 - acc: 0.2046 - val_loss: 2.0812 - val_acc: 0.1688
# Epoch 21/150
#  - 1s - loss: 2.0736 - acc: 0.2028 - val_loss: 2.0854 - val_acc: 0.1724
# Epoch 22/150
#  - 1s - loss: 2.0709 - acc: 0.2080 - val_loss: 2.0853 - val_acc: 0.1759
# Epoch 23/150
#  - 1s - loss: 2.0713 - acc: 0.2124 - val_loss: 2.0797 - val_acc: 0.1724
# Epoch 24/150
#  - 1s - loss: 2.0690 - acc: 0.2096 - val_loss: 2.0822 - val_acc: 0.1670
# Epoch 25/150
#  - 1s - loss: 2.0686 - acc: 0.2066 - val_loss: 2.0781 - val_acc: 0.1777
# Epoch 26/150
#  - 1s - loss: 2.0671 - acc: 0.2102 - val_loss: 2.0802 - val_acc: 0.1724
# Epoch 27/150
#  - 1s - loss: 2.0719 - acc: 0.2078 - val_loss: 2.0752 - val_acc: 0.1795
# Epoch 28/150
#  - 1s - loss: 2.0669 - acc: 0.2066 - val_loss: 2.0784 - val_acc: 0.1688
# Epoch 29/150
#  - 1s - loss: 2.0670 - acc: 0.2102 - val_loss: 2.0810 - val_acc: 0.1813
# Epoch 30/150
#  - 1s - loss: 2.0636 - acc: 0.2152 - val_loss: 2.0744 - val_acc: 0.1813
# Epoch 31/150
#  - 1s - loss: 2.0630 - acc: 0.2142 - val_loss: 2.0734 - val_acc: 0.1741
# Epoch 32/150
#  - 1s - loss: 2.0584 - acc: 0.2170 - val_loss: 2.0721 - val_acc: 0.1867
# Epoch 33/150
#  - 1s - loss: 2.0582 - acc: 0.2263 - val_loss: 2.0689 - val_acc: 0.1777
# Epoch 34/150
#  - 1s - loss: 2.0597 - acc: 0.2212 - val_loss: 2.0713 - val_acc: 0.1831
# Epoch 35/150
#  - 1s - loss: 2.0563 - acc: 0.2216 - val_loss: 2.0675 - val_acc: 0.1885
# Epoch 36/150
#  - 1s - loss: 2.0575 - acc: 0.2198 - val_loss: 2.0694 - val_acc: 0.1885
# Epoch 37/150
#  - 1s - loss: 2.0519 - acc: 0.2277 - val_loss: 2.0689 - val_acc: 0.1993
# Epoch 38/150
#  - 1s - loss: 2.0532 - acc: 0.2242 - val_loss: 2.0639 - val_acc: 0.1903
# Epoch 39/150
#  - 1s - loss: 2.0508 - acc: 0.2204 - val_loss: 2.0651 - val_acc: 0.1957
# Epoch 40/150
#  - 1s - loss: 2.0505 - acc: 0.2226 - val_loss: 2.0632 - val_acc: 0.1921
# Epoch 41/150
#  - 1s - loss: 2.0469 - acc: 0.2232 - val_loss: 2.0578 - val_acc: 0.1975
# Epoch 42/150
#  - 1s - loss: 2.0432 - acc: 0.2236 - val_loss: 2.0605 - val_acc: 0.1939
# Epoch 43/150
#  - 1s - loss: 2.0423 - acc: 0.2317 - val_loss: 2.0605 - val_acc: 0.1867
# Epoch 44/150
#  - 1s - loss: 2.0422 - acc: 0.2293 - val_loss: 2.0561 - val_acc: 0.1993
# Epoch 45/150
#  - 1s - loss: 2.0416 - acc: 0.2220 - val_loss: 2.0560 - val_acc: 0.1957
# Epoch 46/150
#  - 1s - loss: 2.0377 - acc: 0.2317 - val_loss: 2.0542 - val_acc: 0.1957
# Epoch 47/150
#  - 1s - loss: 2.0428 - acc: 0.2248 - val_loss: 2.0540 - val_acc: 0.1975
# Epoch 48/150
#  - 1s - loss: 2.0415 - acc: 0.2238 - val_loss: 2.0556 - val_acc: 0.2011
# Epoch 49/150
#  - 1s - loss: 2.0380 - acc: 0.2232 - val_loss: 2.0520 - val_acc: 0.2011
# Epoch 50/150
#  - 1s - loss: 2.0369 - acc: 0.2303 - val_loss: 2.0590 - val_acc: 0.2011
# Epoch 51/150
#  - 1s - loss: 2.0328 - acc: 0.2313 - val_loss: 2.0511 - val_acc: 0.2101
# Epoch 52/150
#  - 1s - loss: 2.0335 - acc: 0.2349 - val_loss: 2.0500 - val_acc: 0.1993
# Epoch 53/150
#  - 1s - loss: 2.0301 - acc: 0.2333 - val_loss: 2.0496 - val_acc: 0.1993
# Epoch 54/150
#  - 1s - loss: 2.0323 - acc: 0.2297 - val_loss: 2.0486 - val_acc: 0.2083
# Epoch 55/150
#  - 1s - loss: 2.0284 - acc: 0.2263 - val_loss: 2.0476 - val_acc: 0.2065
# Epoch 56/150
#  - 1s - loss: 2.0296 - acc: 0.2315 - val_loss: 2.0455 - val_acc: 0.2190
# Epoch 57/150
#  - 1s - loss: 2.0277 - acc: 0.2371 - val_loss: 2.0397 - val_acc: 0.2118
# Epoch 58/150
#  - 1s - loss: 2.0248 - acc: 0.2401 - val_loss: 2.0456 - val_acc: 0.2011
# Epoch 59/150
#  - 1s - loss: 2.0251 - acc: 0.2383 - val_loss: 2.0462 - val_acc: 0.2083
# Epoch 60/150
#  - 1s - loss: 2.0228 - acc: 0.2339 - val_loss: 2.0438 - val_acc: 0.2136
# Epoch 61/150
#  - 1s - loss: 2.0223 - acc: 0.2351 - val_loss: 2.0409 - val_acc: 0.1993
# Epoch 62/150
#  - 1s - loss: 2.0218 - acc: 0.2313 - val_loss: 2.0453 - val_acc: 0.2029
# Epoch 63/150
#  - 1s - loss: 2.0238 - acc: 0.2373 - val_loss: 2.0418 - val_acc: 0.2101
# Epoch 64/150
#  - 1s - loss: 2.0156 - acc: 0.2391 - val_loss: 2.0466 - val_acc: 0.2172
# Epoch 65/150
#  - 1s - loss: 2.0144 - acc: 0.2429 - val_loss: 2.0420 - val_acc: 0.2047
# Epoch 66/150
#  - 1s - loss: 2.0163 - acc: 0.2343 - val_loss: 2.0378 - val_acc: 0.2334
# Epoch 67/150
#  - 1s - loss: 2.0146 - acc: 0.2353 - val_loss: 2.0489 - val_acc: 0.1957
# Epoch 68/150
#  - 1s - loss: 2.0162 - acc: 0.2443 - val_loss: 2.0364 - val_acc: 0.2029
# Epoch 69/150
#  - 1s - loss: 2.0131 - acc: 0.2397 - val_loss: 2.0404 - val_acc: 0.2208
# Epoch 70/150
#  - 1s - loss: 2.0103 - acc: 0.2367 - val_loss: 2.0374 - val_acc: 0.2280
# Epoch 71/150
#  - 1s - loss: 2.0061 - acc: 0.2455 - val_loss: 2.0342 - val_acc: 0.2065
# Epoch 72/150
#  - 1s - loss: 2.0108 - acc: 0.2369 - val_loss: 2.0402 - val_acc: 0.2136
# Epoch 73/150
#  - 1s - loss: 2.0092 - acc: 0.2363 - val_loss: 2.0381 - val_acc: 0.2101
# Epoch 74/150
#  - 1s - loss: 2.0032 - acc: 0.2401 - val_loss: 2.0330 - val_acc: 0.2208
# Epoch 75/150
#  - 1s - loss: 2.0041 - acc: 0.2343 - val_loss: 2.0330 - val_acc: 0.2136
# Epoch 76/150
#  - 1s - loss: 1.9979 - acc: 0.2525 - val_loss: 2.0408 - val_acc: 0.2154
# Epoch 77/150
#  - 1s - loss: 1.9988 - acc: 0.2451 - val_loss: 2.0385 - val_acc: 0.2190
# Epoch 78/150
#  - 1s - loss: 1.9983 - acc: 0.2457 - val_loss: 2.0360 - val_acc: 0.2244
# Epoch 79/150
#  - 1s - loss: 1.9934 - acc: 0.2481 - val_loss: 2.0348 - val_acc: 0.2154
# Epoch 80/150
#  - 1s - loss: 1.9930 - acc: 0.2535 - val_loss: 2.0403 - val_acc: 0.2101
# Epoch 81/150
#  - 1s - loss: 1.9986 - acc: 0.2419 - val_loss: 2.0327 - val_acc: 0.2101
# Epoch 82/150
#  - 1s - loss: 1.9895 - acc: 0.2489 - val_loss: 2.0446 - val_acc: 0.2208
# Epoch 83/150
#  - 1s - loss: 1.9842 - acc: 0.2495 - val_loss: 2.0289 - val_acc: 0.2226
# Epoch 84/150
#  - 1s - loss: 1.9893 - acc: 0.2485 - val_loss: 2.0331 - val_acc: 0.2280
# Epoch 85/150
#  - 1s - loss: 1.9896 - acc: 0.2461 - val_loss: 2.0216 - val_acc: 0.2136
# Epoch 86/150
#  - 1s - loss: 1.9832 - acc: 0.2441 - val_loss: 2.0351 - val_acc: 0.2298
# Epoch 87/150
#  - 1s - loss: 1.9879 - acc: 0.2497 - val_loss: 2.0246 - val_acc: 0.2262
# Epoch 88/150
#  - 1s - loss: 1.9814 - acc: 0.2513 - val_loss: 2.0203 - val_acc: 0.2334
# Epoch 89/150
#  - 1s - loss: 1.9765 - acc: 0.2543 - val_loss: 2.0296 - val_acc: 0.2316
# Epoch 90/150
#  - 1s - loss: 1.9754 - acc: 0.2521 - val_loss: 2.0233 - val_acc: 0.2334
# Epoch 91/150
#  - 1s - loss: 1.9742 - acc: 0.2581 - val_loss: 2.0252 - val_acc: 0.2226
# Epoch 92/150
#  - 1s - loss: 1.9755 - acc: 0.2491 - val_loss: 2.0217 - val_acc: 0.2262
# Epoch 93/150
#  - 1s - loss: 1.9676 - acc: 0.2583 - val_loss: 2.0135 - val_acc: 0.2388
# Epoch 94/150
#  - 1s - loss: 1.9659 - acc: 0.2547 - val_loss: 2.0140 - val_acc: 0.2244
# Epoch 95/150
#  - 1s - loss: 1.9593 - acc: 0.2613 - val_loss: 2.0086 - val_acc: 0.2549
# Epoch 96/150
#  - 1s - loss: 1.9630 - acc: 0.2629 - val_loss: 2.0075 - val_acc: 0.2298
# Epoch 97/150
#  - 1s - loss: 1.9553 - acc: 0.2531 - val_loss: 2.0217 - val_acc: 0.2154
# Epoch 98/150
#  - 1s - loss: 1.9577 - acc: 0.2633 - val_loss: 2.0005 - val_acc: 0.2244
# Epoch 99/150
#  - 1s - loss: 1.9545 - acc: 0.2643 - val_loss: 2.0014 - val_acc: 0.2388
# Epoch 100/150
#  - 1s - loss: 1.9486 - acc: 0.2621 - val_loss: 2.0083 - val_acc: 0.2316
# Epoch 101/150
#  - 1s - loss: 1.9487 - acc: 0.2643 - val_loss: 2.0086 - val_acc: 0.2208
# Epoch 102/150
#  - 1s - loss: 1.9476 - acc: 0.2619 - val_loss: 2.0179 - val_acc: 0.2513
# Epoch 103/150
#  - 1s - loss: 1.9433 - acc: 0.2683 - val_loss: 2.0086 - val_acc: 0.2460
# Epoch 104/150
#  - 1s - loss: 1.9448 - acc: 0.2681 - val_loss: 2.0101 - val_acc: 0.2118
# Epoch 105/150
#  - 1s - loss: 1.9481 - acc: 0.2591 - val_loss: 2.0086 - val_acc: 0.2334
# Epoch 106/150
#  - 1s - loss: 1.9374 - acc: 0.2705 - val_loss: 2.0001 - val_acc: 0.2280
# Epoch 107/150
#  - 1s - loss: 1.9258 - acc: 0.2705 - val_loss: 2.0056 - val_acc: 0.2352
# Epoch 108/150
#  - 1s - loss: 1.9399 - acc: 0.2647 - val_loss: 2.0072 - val_acc: 0.2352
# Epoch 109/150
#  - 1s - loss: 1.9315 - acc: 0.2725 - val_loss: 2.0076 - val_acc: 0.2316
# Epoch 110/150
#  - 1s - loss: 1.9248 - acc: 0.2717 - val_loss: 2.0003 - val_acc: 0.2334
# Epoch 111/150
#  - 1s - loss: 1.9282 - acc: 0.2798 - val_loss: 2.0321 - val_acc: 0.2280
# Epoch 112/150
#  - 1s - loss: 1.9294 - acc: 0.2729 - val_loss: 2.0041 - val_acc: 0.2496
# Epoch 113/150
#  - 1s - loss: 1.9240 - acc: 0.2754 - val_loss: 2.0110 - val_acc: 0.2388
# Epoch 114/150
#  - 1s - loss: 1.9131 - acc: 0.2796 - val_loss: 2.0035 - val_acc: 0.2406
# Epoch 115/150
#  - 1s - loss: 1.9151 - acc: 0.2756 - val_loss: 1.9893 - val_acc: 0.2531
# Epoch 116/150
#  - 1s - loss: 1.9130 - acc: 0.2816 - val_loss: 1.9894 - val_acc: 0.2316
# Epoch 117/150
#  - 1s - loss: 1.9097 - acc: 0.2834 - val_loss: 1.9928 - val_acc: 0.2298
# Epoch 118/150
#  - 1s - loss: 1.9151 - acc: 0.2723 - val_loss: 1.9998 - val_acc: 0.2442
# Epoch 119/150
#  - 1s - loss: 1.9051 - acc: 0.2816 - val_loss: 1.9948 - val_acc: 0.2388
# Epoch 120/150
#  - 1s - loss: 1.9024 - acc: 0.2824 - val_loss: 1.9928 - val_acc: 0.2424
# Epoch 121/150
#  - 1s - loss: 1.8936 - acc: 0.2870 - val_loss: 2.0007 - val_acc: 0.2388
# Epoch 122/150
#  - 1s - loss: 1.8904 - acc: 0.2788 - val_loss: 1.9834 - val_acc: 0.2478
# Epoch 123/150
#  - 1s - loss: 1.8998 - acc: 0.2866 - val_loss: 1.9860 - val_acc: 0.2442
# Epoch 124/150
#  - 1s - loss: 1.8989 - acc: 0.2846 - val_loss: 1.9896 - val_acc: 0.2496
# Epoch 125/150
#  - 1s - loss: 1.8893 - acc: 0.2894 - val_loss: 1.9863 - val_acc: 0.2478
# Epoch 126/150
#  - 1s - loss: 1.8835 - acc: 0.2852 - val_loss: 1.9903 - val_acc: 0.2567
# Epoch 127/150
#  - 1s - loss: 1.8827 - acc: 0.2960 - val_loss: 1.9918 - val_acc: 0.2585
# Epoch 128/150
#  - 1s - loss: 1.8815 - acc: 0.2908 - val_loss: 1.9945 - val_acc: 0.2406
# Epoch 129/150
#  - 1s - loss: 1.8765 - acc: 0.2828 - val_loss: 2.0052 - val_acc: 0.2262
# Epoch 130/150
#  - 1s - loss: 1.8909 - acc: 0.2739 - val_loss: 1.9979 - val_acc: 0.2352
# Epoch 131/150
#  - 1s - loss: 1.8895 - acc: 0.2834 - val_loss: 1.9847 - val_acc: 0.2513
# Epoch 132/150
#  - 1s - loss: 1.8701 - acc: 0.2894 - val_loss: 1.9819 - val_acc: 0.2388
# Epoch 133/150
#  - 1s - loss: 1.8663 - acc: 0.2918 - val_loss: 1.9954 - val_acc: 0.2513
# Epoch 134/150
#  - 1s - loss: 1.8730 - acc: 0.2892 - val_loss: 1.9759 - val_acc: 0.2585
# Epoch 135/150
#  - 1s - loss: 1.8631 - acc: 0.3004 - val_loss: 1.9856 - val_acc: 0.2442
# Epoch 136/150
#  - 1s - loss: 1.8592 - acc: 0.2996 - val_loss: 1.9850 - val_acc: 0.2496
# Epoch 137/150
#  - 1s - loss: 1.8581 - acc: 0.3022 - val_loss: 1.9948 - val_acc: 0.2424
# Epoch 138/150
#  - 1s - loss: 1.8565 - acc: 0.2930 - val_loss: 1.9848 - val_acc: 0.2567
# Epoch 139/150
#  - 1s - loss: 1.8559 - acc: 0.3012 - val_loss: 1.9970 - val_acc: 0.2496
# Epoch 140/150
#  - 1s - loss: 1.8521 - acc: 0.3050 - val_loss: 1.9722 - val_acc: 0.2531
# Epoch 141/150
#  - 1s - loss: 1.8509 - acc: 0.3070 - val_loss: 1.9794 - val_acc: 0.2460
# Epoch 142/150
#  - 1s - loss: 1.8439 - acc: 0.2934 - val_loss: 1.9873 - val_acc: 0.2478
# Epoch 143/150
#  - 1s - loss: 1.8416 - acc: 0.3072 - val_loss: 2.0113 - val_acc: 0.2496
# Epoch 144/150
#  - 1s - loss: 1.8427 - acc: 0.3048 - val_loss: 1.9779 - val_acc: 0.2549
# Epoch 145/150
#  - 1s - loss: 1.8377 - acc: 0.3084 - val_loss: 1.9868 - val_acc: 0.2513
# Epoch 146/150
#  - 1s - loss: 1.8265 - acc: 0.3056 - val_loss: 1.9865 - val_acc: 0.2513
# Epoch 147/150
#  - 1s - loss: 1.8339 - acc: 0.3084 - val_loss: 1.9961 - val_acc: 0.2513
# Epoch 148/150
#  - 1s - loss: 1.8318 - acc: 0.3070 - val_loss: 1.9767 - val_acc: 0.2513
# Epoch 149/150
#  - 1s - loss: 1.8157 - acc: 0.3102 - val_loss: 1.9889 - val_acc: 0.2513
# Epoch 150/150
#  - 1s - loss: 1.8159 - acc: 0.3180 - val_loss: 2.0048 - val_acc: 0.2244

# %%
history.loss_plot('epoch')
loss_4, accuracy_4 = model.evaluate(test_x, test_y)
print('test loss: ', loss_4)
print('test accuracy: ', accuracy_4)
# Out:
# 618/618 [==============================] - 0s 155us/step
# test loss:  2.073003372328181
# test accuracy:  0.25080906153689697

# %%
accuracy=[accuracy_1*100,accuracy_2*100,accuracy_3*100,accuracy_4*100]
number=[1,2,3,4]
plt.plot(number, accuracy)
plt.xlabel("accuracy")
plt.ylabel("percent")
plt.show()
